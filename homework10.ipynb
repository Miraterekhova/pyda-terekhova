# %% [markdown]
# ## Задание 1

# %% [markdown]
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
ratings = pd.read_csv('ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
ratings.groupby('movieId').count().sort_values('rating', ascending=False).head()
# Out:
#          userId  rating  timestamp
# movieId
# 356       81491   81491      81491
# 318       81482   81482      81482
# 296       79672   79672      79672
# 593       74127   74127      74127
# 2571      72674   72674      72674

# %%
ratings [ ratings.rating == 5 ].head() #получаем все фильмы с оценкой 5
# Out:
#     userId  movieId  rating   timestamp
# 0        1      296     5.0  1147880044
# 2        1      307     5.0  1147868828
# 3        1      665     5.0  1147878820
# 8        1     1237     5.0  1147868839
# 18       1     2632     5.0  1147878248

# %% [markdown]
# ## Задание 2

# %% [markdown]
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
filtered = data[ ((data['country']=='Latvia') | (data['country']=='Lithuania') | (data['country']=='Estonia'))
                & ((data['category']==4) | (data['category']==12) | (data['category']==21))
                & ((data['year'] > 2005) & (data['year']<2010))]
result = filtered[ filtered.quantity >=0 ]
result.quantity.sum()
# Out:
# 164555.0

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.

# %%
page_url = 'https://www.finanz.ru/valyuty/v-realnom-vremeni'

df = pd.read_html(page_url,  attrs = {'class': 'header_user_pricebox'}, encoding='utf-8')
df2 = pd.read_html(page_url,  attrs = {'class': 'quote_list'}, encoding='utf-8')

# %%
df[:5]
# Out:
# [     0       1      2        3       4      5        6       7     8   \
#  0  ММВБ   2 999   0,4%   Nasdaq  11 554  -1,4%  Биткойн  15 409  0,7%
#  1   РТС   1 233  -0,3%   S&P500   3 546  -0,1%    Нефть     441  0,1%
#  2   Dow  29 421   0,9%  FTSE100   6 297   1,8%   Золото   1 880  0,1%
#
#          9       10     11
#  0  USD/RUB  763471  -0,4%
#  1  EUR/RUB  903045  -0,3%
#  2  EUR/USD   11827   0,1%  ]

# %%
df2[:5]
# Out:
# [    Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
#  0          NaN            GBP/RUB      1014828      -              1017342
#  1          NaN            EUR/RUB       904882      -               905980
#  2          NaN            USD/RUB       768520      -               766320
#  3          NaN            JPY/RUB        07281      -                07283
#  4          NaN            CNY/RUB       115872      -               115874
#  5          NaN            CHF/RUB       837732      -               838078
#  6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
#  7          NaN            EUR/USD        11773      -                11821
#  8          NaN            EUR/GBP        08918      -                08908
#  9          NaN            EUR/JPY      1242815      -              1244150
#  10         NaN            EUR/CHF        10799      -                10811
# ...
